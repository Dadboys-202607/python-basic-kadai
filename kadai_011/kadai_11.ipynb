# %%
array = ["水","金","地","火","木","土","天","海","冥"]

for ary in array:
        print(ary)

print("for文出力終了")

i = 0
while i < len(array):
     print(array[i])
     i += 1

print("while文出力終了")
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# for文出力終了
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# while文出力終了

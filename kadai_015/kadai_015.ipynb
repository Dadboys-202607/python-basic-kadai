# %%
class Human:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def printinfo(self):
        print(self.name)
        print(self.age)

Shain1 = Human("Tanaka", 30)
Shain1.printinfo()
# Out:
# Tanaka
# 30

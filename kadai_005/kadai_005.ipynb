# %%
'''
上辺：10cm
下辺：20cm
高さ：5cm

公式：台形の面積 =（上辺＋下辺）× 高さ ÷ 2
'''

Jouhen = 10
Kahen = 20
Hight = 5

Area = (Jouhen + Kahen) * Hight / 2
# 台形の面積の値の確認
print(Area)

print("台形の面積は" + str(Area) + "cm²")
# Out:
# 75.0
# 台形の面積は75.0cm²
